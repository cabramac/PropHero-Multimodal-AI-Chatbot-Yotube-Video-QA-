# %% [markdown]
# **3. Qustion-Answering (QA) Chain + Evaluation**

# %% [markdown]
# **Key Objectives Delivered**:
# 1) **Embeddings (MiniLM-L6-v2)**: This converts the text transcript of the Yotube and blogs into vectors that capture meaning.
# 2) **Retriver/Vector Store Set-up (Chroma DB)**: Our database that stores our vectors and allows fast similarity search.
# 3) **Configuration of Ranker Retriever**:
# 4) **LLM Configuration**: The brrain that reads retrieved documents and generates the answers
# 5) **Multi-Query Retriever / Helper function Evaluation (ask_rag) & QA chain**:
# 5) **Testing**: Ran list of questions to test accuracy and hallucination resistance.

# %% [markdown]
# 3.1 Importing the corresponding libraries we are going to use

# %%
import os

os.environ["OPENAI_API_KEY"] =

# %%
from langchain_community.vectorstores import Chroma
from langchain_community.embeddings import HuggingFaceEmbeddings

embedding_function = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

knowledge_vectorstore = Chroma(
    collection_name="prophero_knowledge",
    persist_directory="data/chroma_db",
    embedding_function=embedding_function,
)

print("Number of documents in Chroma collection:", 
      knowledge_vectorstore._collection.count())
# Out:
# Number of documents in Chroma collection: 50

# %% [markdown]
# 3.2 Creating retrievers. We need this step to define how my systems retrieves the information from the Chroma database.

# %%
retriever = knowledge_vectorstore.as_retriever(
    search_type="similarity",
    search_kwargs={"k": 10}
)

# %%
{
  'title': 'The Most Common Property Investment Mistakes That Can Easily Be Avoided',
  'video_id': 'blog_mistakes',
  'url': 'https://www.prophero.com/the-most-common-property-investment-mistakes-that-can-easily-be-avoided/',
  'source_type': 'blog'
}
# Out:
# {'title': 'The Most Common Property Investment Mistakes That Can Easily Be Avoided',
#  'video_id': 'blog_mistakes',
#  'url': 'https://www.prophero.com/the-most-common-property-investment-mistakes-that-can-easily-be-avoided/',
#  'source_type': 'blog'}

# %%
# 1. Ground truth based in video_id / blog_id

ground_truth = {
    "What does PropHero do?": [
        "prophero_video_1",
        "prophero_video_2",
        "prophero_video_3",
        "blog_mistakes",
    ],
    "Does PropHero use AI?": [
        "prophero_video_3",
        "blog_mistakes",
        "blog_property_vs_shares",
    ],
    "Who founded PropHero?": [
        "blog_capital_gains",
        "blog_mistakes",
    ],
}

# %%
import numpy as np

# 2. Measuring key metrics for our retriver: precisión@k, recall@k, MRR

def precision_at_k(relevant_ids, retrieved_ids, k=5):
    retrieved_k = retrieved_ids[:k]
    if len(retrieved_k) == 0:
        return 0.0
    hits = sum(doc_id in relevant_ids for doc_id in retrieved_k)
    return hits / len(retrieved_k)


def recall_at_k(relevant_ids, retrieved_ids, k=5):
    if len(relevant_ids) == 0:
        return 0.0
    retrieved_k = retrieved_ids[:k]
    hits = sum(doc_id in relevant_ids for doc_id in retrieved_k)
    return hits / len(relevant_ids)


def mrr_score(relevant_ids, retrieved_ids):
    for rank, doc_id in enumerate(retrieved_ids, start=1):
        if doc_id in relevant_ids:
            return 1.0 / rank
    return 0.0


def evaluate_retriever(queries, retriever, ground_truth, top_k=5):
    precision_scores = []
    recall_scores = []
    mrr_scores = []

    for q in queries:
    
        docs = retriever.invoke(q)

        retrieved_ids = [doc.metadata.get("video_id") for doc in docs]

        relevant = ground_truth[q]

        # Calcular métricas
        precision_scores.append(precision_at_k(relevant, retrieved_ids, k=top_k))
        recall_scores.append(recall_at_k(relevant, retrieved_ids, k=top_k))
        mrr_scores.append(mrr_score(relevant, retrieved_ids))

    return {
        "precision@k": float(np.mean(precision_scores)),
        "recall@k": float(np.mean(recall_scores)),
        "mrr": float(np.mean(mrr_scores)),
    }

# %%
queries = list(ground_truth.keys())

results_old = evaluate_retriever(
    queries=queries,
    retriever=retriever,
    ground_truth=ground_truth,
    top_k=5,
)

results_old
# Out:
# {'precision@k': 0.6, 'recall@k': 1.0, 'mrr': 1.0}

# %%
import json

with open("results_old.json", "w") as f:
    json.dump(results_old, f, indent=4)

print("Old evaluation saved!")
# Out:
# Old evaluation saved!

# %% [markdown]
# 3.3 Defining the LLM (the brain that will generate the answers)

# %%
from langchain.chat_models import ChatOpenAI

# %%
llm = ChatOpenAI(
    model_name="gpt-4o-mini", 
    temperature=0.3          
)

# %% [markdown]
# 3.4 MultiQuery Retriver : Help us expanding the search. LLM generates multiple paraphrased queries / runs similarity search for each and combines the result. "ask the question in several smart ways --> gathers more possible answers"

# %%
try:
    from langchain.retrievers.multi_query import MultiQueryRetriever
except ImportError:
    from langchain_community.retrievers import MultiQueryRetriever

multiquery_retriever = MultiQueryRetriever.from_llm(
    retriever=retriever,  
    llm=llm,          
    include_original=True 
)

multiquery_retriever
# Out:
# MultiQueryRetriever(retriever=VectorStoreRetriever(tags=['Chroma', 'HuggingFaceEmbeddings'], vectorstore=<langchain_community.vectorstores.chroma.Chroma object at 0x0000026F4DD62490>, search_kwargs={'k': 10}), llm_chain=PromptTemplate(input_variables=['question'], input_types={}, partial_variables={}, template='You are an AI language model assistant. Your task is\n    to generate 3 different versions of the given user\n    question to retrieve relevant documents from a vector  database.\n    By generating multiple perspectives on the user question,\n    your goal is to help the user overcome some of the limitations\n    of distance-based similarity search. Provide these alternative\n    questions separated by newlines. Original question: {question}')
# | ChatOpenAI(client=<openai.resources.chat.completions.completions.Completions object at 0x0000026F4E56AC50>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x0000026F4E56B190>, model_name='gpt-4o-mini', temperature=0.3, model_kwargs={}, openai_api_key='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', openai_proxy='')
# | LineListOutputParser(), include_original=True)

# %% [markdown]
# 3.4 Ranker Retriever: Filters and prioritize. Makes sure that recorders the chunks from the most to the least relevant based on the user query.

# %%
from typing import List
from sentence_transformers import CrossEncoder


try:
    from langchain_core.retrievers import BaseRetriever
    from langchain_core.documents import Document
except ImportError:
   
    from langchain.retrievers import BaseRetriever
    from langchain.schema import Document


class CrossEncoderRerankRetriever(BaseRetriever):
    """
    LangChain-compatible retriever that:
    1) Uses a base retriever (Chroma) to get k_initial docs
    2) Uses a CrossEncoder reranker to score (query, doc)
    3) Returns the top k_final docs
    """

    base_retriever: BaseRetriever
    reranker: CrossEncoder
    k_initial: int = 10
    k_final: int = 4

    def _get_relevant_documents(self, query: str) -> List[Document]:
        
        docs = self.base_retriever.get_relevant_documents(query)
        if not docs:
            return []

        docs = docs[: self.k_initial]
    
        pairs = [(query, d.page_content) for d in docs]

        scores = self.reranker.predict(pairs)

        scored_docs = sorted(zip(scores, docs), key=lambda x: x[0], reverse=True)
        top_docs = [doc for score, doc in scored_docs[: self.k_final]]
        return top_docs

    async def _aget_relevant_documents(self, query: str) -> List[Document]:
     
        return self._get_relevant_documents(query)

reranker_model = CrossEncoder("cross-encoder/ms-marco-MiniLM-L-6-v2")

rerank_retriever = CrossEncoderRerankRetriever(
    base_retriever=retriever,   
    reranker=reranker_model,
    k_initial=10,
    k_final=4,
)

# %% [markdown]
# 3.6 QA Chain. This controld how the LLM uses context

# %%
#from langchain.chains import RetrievalQA

qa_chain = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=multiquery_retriever,   
    return_source_documents=True
)

# %%
from langchain.chains import LLMChain
from langchain.chains.combine_documents.stuff import StuffDocumentsChain

# 1) LLMChain que usa tu PromptTemplate (aquí sí se respeta)
llm_chain = LLMChain(
    llm=llm,
    prompt=qa_prompt,
)

# 2) CombineDocumentsChain que junta documentos + tu prompt
doc_chain = StuffDocumentsChain(
    llm_chain=llm_chain,
    document_variable_name="context",
)

# 3) Construimos la RetrievalQA manualmente
qa_chain = RetrievalQA(
    retriever=multiquery_retriever,
    combine_documents_chain=doc_chain,
    return_source_documents=True,
)
# Out:
# C:\Users\macat\AppData\Local\Temp\ipykernel_21880\1995366142.py:5: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   llm_chain = LLMChain(
# C:\Users\macat\AppData\Local\Temp\ipykernel_21880\1995366142.py:11: LangChainDeprecationWarning: This class is deprecated. Use the `create_stuff_documents_chain` constructor instead. See migration guide here: https://python.langchain.com/docs/versions/migrating_chains/stuff_docs_chain/
#   doc_chain = StuffDocumentsChain(
# C:\Users\macat\AppData\Local\Temp\ipykernel_21880\1995366142.py:17: LangChainDeprecationWarning: This class is deprecated. Use the `create_retrieval_chain` constructor instead. See migration guide here: https://python.langchain.com/docs/versions/migrating_chains/retrieval_qa/
#   qa_chain = RetrievalQA(

# %% [markdown]
# 3.7 Helper RAG Function for testing. It help us to shortcut in a way that sends the question into the full RAG chain  (multi_source_qa_chain) , prints clear answers, and even prints sources.

# %%
def ask_rag(question: str, show_sources: bool = True):
    """
    Sends a question to the RAG system and prints the full-sentence answer.
    Optionally shows sources and chunk previews.
    """
    response = qa_chain({"query": question})

    print("\n=== ANSWER ===\n")
    print(response["result"])

    if show_sources:
        print("\n=== SOURCES USED ===\n")
        for i, doc in enumerate(response["source_documents"], start=1):
            meta = doc.metadata
            preview = doc.page_content[:250].replace("\n", " ")

            print(f"Source {i}:")
            print(f"  - Type: {meta.get('source_type')}")
            print(f"  - Title: {meta.get('title')}")
            print(f"  - URL: {meta.get('url')}")
            print(f"  - Chunk Preview: {preview}...")
            print()

# %%
from langchain.prompts import PromptTemplate

qa_prompt = PromptTemplate(
    input_variables=["context", "question"],
    template="""
You are a helpful and friendly AI assistant for property investors.

Your task is to answer ONLY using the information in the context below.

❗ IMPORTANT: Your answer MUST follow these rules:
- Maximum **1 sentence**
- Short, clear and to the point
- No long explanations
- No extra information not in the context
- If the answer is not in the context, say: "Sorry, I couldn't find information about that."

---

Context:
{context}

Question:
{question}

Short answer (max 1 sentence):
"""
)

# %% [markdown]
# 3.8 Testing

# %%
test_questions = [
    "Is PropHero a company that focuses on property investment?",
    "Does PropHero use artificial intelligence for decision-making?",
    "Does PropHero specialize in commercial properties?",
    "Who is one of the co-founders of PropHero?",
    "What kind of platform is PropHero described as?",
    "What problem does PropHero aim to solve for investors?",
    "What does PropHero send to users after they invest?",
    "What is the capital of Brazil according to PropHero?",  # hallucination test
    "Does the text describe safari tourism in Africa?"        # totally off-topic
]

# %%
for i, question in enumerate(test_questions, start=1):
    print(f"\n{'=' * 60}")
    print(f"❓ Question {i}: {question}\n")
    
    ask_rag(question, show_sources=True)
    
    print("\n")
# Out:
# ============================================================
# ❓ Question 1: Is PropHero a company that focuses on property investment?
#
#
# === ANSWER ===
#
# Yes, PropHero is a company that focuses on property investment.
#
# === SOURCES USED ===
#
# Source 1:
#   - Type: blog
#   - Title: Are You Calculating Rental Yield Correctly?
#   - URL: https://www.prophero.com/are-you-calculating-rental-yield-correctly/
#   - Chunk Preview: into account other expense associate with property ownership , such as property management fee , maintenance cost , property taxis , and insurance . net rental yield this calculation consider the net income from the property after deduct all associat...
#
# Source 2:
#   - Type: video
#   - Title: PropHero – Intro Video 3
#   - URL: https://www.youtube.com/watch?v=5Kca3nOrefY
#   - Chunk Preview: portfolio use each successful investment to power the next , create a snowball of wealth over time . and that be why we create prop hero to help everyday aussie find , buy and manage high return low risk investment property . unlike other platform th...
#
# Source 3:
#   - Type: video
#   - Title: PropHero – Intro Video 1
#   - URL: https://www.youtube.com/watch?v=ED3eypjlfrY
#   - Chunk Preview: hi , my name be michael roger . I m one of the co - founder of prop hero . in this video , I m go to show you how we be use datum to find the good deal . all right , let s start with the absolute basic . in a very , very simplified view , a great inv...
#
# Source 4:
#   - Type: video
#   - Title: PropHero – Intro Video 3
#   - URL: https://www.youtube.com/watch?v=5Kca3nOrefY
#   - Chunk Preview: ugh out these key phase . phase number one , it s acquisition . we help you build a solid foundation with high growth property . number two , it s consolidation . we use each investment to feel the next . and number three be lifestyle . we handle pro...
#
# Source 5:
#   - Type: blog
#   - Title: Property vs Shares: What’s the Difference & Which is Better for You?
#   - URL: https://www.prophero.com/property-vs-shares-whats-the-difference-which-is-better-for-you/
#   - Chunk Preview: down all the time . in property , despite the change and boom , they be more stable over time and you win t be at risk of lose your investment the same way you could with the stock market . in short , both type of investment have their advantage , bu...
#
# Source 6:
#   - Type: blog
#   - Title: The Most Common Property Investment Mistakes That Can Easily Be Avoided
#   - URL: https://www.prophero.com/the-most-common-property-investment-mistakes-that-can-easily-be-avoided/
#   - Chunk Preview: use your emotion to guide you it sound weird . we know . but buy property with your emotion be one of the big mistake we see many investor make everyday . maybe they want to invest or buy in an area close to home . or maybe they feel the late propert...
#
# Source 7:
#   - Type: blog
#   - Title: Property vs Shares: What’s the Difference & Which is Better for You?
#   - URL: https://www.prophero.com/property-vs-shares-whats-the-difference-which-is-better-for-you/
#   - Chunk Preview: how it work about us datum and ai press and blog how it work about us datum and ai press and blog en es book a free investment session prophero october 15 , 2025 property vs share what s the difference which be well for you there be so many option wh...
#
# Source 8:
#   - Type: blog
#   - Title: The Most Common Property Investment Mistakes That Can Easily Be Avoided
#   - URL: https://www.prophero.com/the-most-common-property-investment-mistakes-that-can-easily-be-avoided/
#   - Chunk Preview: t prophero how it work datum ai resource press and blog refer a friend frequently ask question 2025 prophero all right reserve term and condition privacy policy cooky policy legal...
#
# Source 9:
#   - Type: blog
#   - Title: The Most Common Property Investment Mistakes That Can Easily Be Avoided
#   - URL: https://www.prophero.com/the-most-common-property-investment-mistakes-that-can-easily-be-avoided/
#   - Chunk Preview: re you live with service like prophero , you do not need to invest in property in your local area anymore . it may be tempting to go to open house in your local area on the weekend to see if you can snag a deal , but it s really not necessary . if yo...
#
# Source 10:
#   - Type: video
#   - Title: PropHero – Intro Video 3
#   - URL: https://www.youtube.com/watch?v=5Kca3nOrefY
#   - Chunk Preview: neighborhood to find the good opportunity for you . we combine this with our expert insight to find high return investment , include off - market property that be not available to the public . so step two , we handle all the buying process for you . ...
#
# Source 11:
#   - Type: blog
#   - Title: Capital Gains 101: A Simplified Guide for Smart Property Investing
#   - URL: https://www.prophero.com/capital-gains-101-a-simplified-guide-for-smart-property-investing/
#   - Chunk Preview: t journey with confidence ? take the first step towards financial success by book a free investment session with our expert . gain valuable insight , ask question , and kickstart your path to make informed investment decision . go back to blog book a...
#
# Source 12:
#   - Type: video
#   - Title: PropHero – Intro Video 2
#   - URL: https://www.youtube.com/watch?v=uxF2IObEzZg
#   - Chunk Preview: hi everyone , I m carol . I m part of the entrepreneurship and innovation ecosystem team , part of investment news at wale . I m here at the sydney startup hub today with one of our amazing founder , pablo , who s the co - founder of prop hero . pabl...
#
# Source 13:
#   - Type: video
#   - Title: PropHero – Intro Video 2
#   - URL: https://www.youtube.com/watch?v=uxF2IObEzZg
#   - Chunk Preview: ll share or you will tell it , hey , have you apply for this ? okay , then you well get a bit more . do you want to tell we a little bit about some accolade you ve recently win ? yes , we win the prop tech startup of the year . congratulation . yes ,...
#
# Source 14:
#   - Type: blog
#   - Title: Property vs Shares: What’s the Difference & Which is Better for You?
#   - URL: https://www.prophero.com/property-vs-shares-whats-the-difference-which-is-better-for-you/
#   - Chunk Preview: tip and trick on the area and location to avoid if you re concerned about invest in property . the benefit of invest in share the stock market be know to be more liquid than invest in tangible property . the high the liquidity mean the fast you ll ha...
#
# Source 15:
#   - Type: video
#   - Title: PropHero – Intro Video 1
#   - URL: https://www.youtube.com/watch?v=ED3eypjlfrY
#   - Chunk Preview: ght away . we actually have a team of , as of today , about like 14 property expert and datum expert who look at these property and run all the analysis that the datum can not see . so there be a real human component to check every single property wi...
#
# Source 16:
#   - Type: blog
#   - Title: The Most Common Property Investment Mistakes That Can Easily Be Avoided
#   - URL: https://www.prophero.com/the-most-common-property-investment-mistakes-that-can-easily-be-avoided/
#   - Chunk Preview: how it work about us datum and ai press and blog how it work about us datum and ai press and blog en es book a free investment session prophero october 13 , 2025 the most common property investment mistake that can easily be avoid believe it or not ,...
#
# Source 17:
#   - Type: video
#   - Title: PropHero – Intro Video 1
#   - URL: https://www.youtube.com/watch?v=ED3eypjlfrY
#   - Chunk Preview: , the quality of the school , crime rate , quality of the street , quality of the property as well . so think about , yeah , improvement potential , running cost , scarcity level , all of that . too many to cite right now , but yeah , we use over 200...
#
#
#
#
# ============================================================
# ❓ Question 2: Does PropHero use artificial intelligence for decision-making?
#
#
# === ANSWER ===
#
# Yes, PropHero uses AI-powered data models to identify high-return properties and guide investment decisions.
#
# === SOURCES USED ===
#
# Source 1:
#   - Type: blog
#   - Title: Property vs Shares: What’s the Difference & Which is Better for You?
#   - URL: https://www.prophero.com/property-vs-shares-whats-the-difference-which-is-better-for-you/
#   - Chunk Preview: ow it works Data & AI Resources Press and Blogs Refer a friend Frequently asked questions 2025 | © PropHero | All rights reserved Terms and Conditions Privacy Policy Cookies Policy Legal...
#
# Source 2:
#   - Type: blog
#   - Title: The Most Common Property Investment Mistakes That Can Easily Be Avoided
#   - URL: https://www.prophero.com/the-most-common-property-investment-mistakes-that-can-easily-be-avoided/
#   - Chunk Preview: t prophero how it work datum ai resource press and blog refer a friend frequently ask question 2025 prophero all right reserve term and condition privacy policy cooky policy legal...
#
# Source 3:
#   - Type: blog
#   - Title: Capital Gains 101: A Simplified Guide for Smart Property Investing
#   - URL: https://www.prophero.com/capital-gains-101-a-simplified-guide-for-smart-property-investing/
#   - Chunk Preview: t journey with confidence ? take the first step towards financial success by book a free investment session with our expert . gain valuable insight , ask question , and kickstart your path to make informed investment decision . go back to blog book a...
#
# Source 4:
#   - Type: blog
#   - Title: Capital Gains 101: A Simplified Guide for Smart Property Investing
#   - URL: https://www.prophero.com/capital-gains-101-a-simplified-guide-for-smart-property-investing/
#   - Chunk Preview: how it work about us datum and ai press and blog how it work about us datum and ai press and blog en es book a free investment session prophero march 4 , 2025 capital gain 101 a simplified guide for smart property investing so you re dive into the wo...
#
# Source 5:
#   - Type: video
#   - Title: PropHero – Intro Video 3
#   - URL: https://www.youtube.com/watch?v=5Kca3nOrefY
#   - Chunk Preview: portfolio use each successful investment to power the next , create a snowball of wealth over time . and that be why we create prop hero to help everyday aussie find , buy and manage high return low risk investment property . unlike other platform th...
#
# Source 6:
#   - Type: blog
#   - Title: The Most Common Property Investment Mistakes That Can Easily Be Avoided
#   - URL: https://www.prophero.com/the-most-common-property-investment-mistakes-that-can-easily-be-avoided/
#   - Chunk Preview: how it work about us datum and ai press and blog how it work about us datum and ai press and blog en es book a free investment session prophero october 13 , 2025 the most common property investment mistake that can easily be avoid believe it or not ,...
#
# Source 7:
#   - Type: video
#   - Title: PropHero – Intro Video 1
#   - URL: https://www.youtube.com/watch?v=ED3eypjlfrY
#   - Chunk Preview: hi , my name be michael roger . I m one of the co - founder of prop hero . in this video , I m go to show you how we be use datum to find the good deal . all right , let s start with the absolute basic . in a very , very simplified view , a great inv...
#
# Source 8:
#   - Type: video
#   - Title: PropHero – Intro Video 2
#   - URL: https://www.youtube.com/watch?v=uxF2IObEzZg
#   - Chunk Preview: hi everyone , I m carol . I m part of the entrepreneurship and innovation ecosystem team , part of investment news at wale . I m here at the sydney startup hub today with one of our amazing founder , pablo , who s the co - founder of prop hero . pabl...
#
# Source 9:
#   - Type: video
#   - Title: PropHero – Intro Video 1
#   - URL: https://www.youtube.com/watch?v=ED3eypjlfrY
#   - Chunk Preview: , the quality of the school , crime rate , quality of the street , quality of the property as well . so think about , yeah , improvement potential , running cost , scarcity level , all of that . too many to cite right now , but yeah , we use over 200...
#
# Source 10:
#   - Type: blog
#   - Title: Property vs Shares: What’s the Difference & Which is Better for You?
#   - URL: https://www.prophero.com/property-vs-shares-whats-the-difference-which-is-better-for-you/
#   - Chunk Preview: how it work about us datum and ai press and blog how it work about us datum and ai press and blog en es book a free investment session prophero october 15 , 2025 property vs share what s the difference which be well for you there be so many option wh...
#
# Source 11:
#   - Type: blog
#   - Title: Property vs Shares: What’s the Difference & Which is Better for You?
#   - URL: https://www.prophero.com/property-vs-shares-whats-the-difference-which-is-better-for-you/
#   - Chunk Preview: down all the time . in property , despite the change and boom , they be more stable over time and you win t be at risk of lose your investment the same way you could with the stock market . in short , both type of investment have their advantage , bu...
#
# Source 12:
#   - Type: video
#   - Title: PropHero – Intro Video 3
#   - URL: https://www.youtube.com/watch?v=5Kca3nOrefY
#   - Chunk Preview: ugh out these key phase . phase number one , it s acquisition . we help you build a solid foundation with high growth property . number two , it s consolidation . we use each investment to feel the next . and number three be lifestyle . we handle pro...
#
#
#
#
# ============================================================
# ❓ Question 3: Does PropHero specialize in commercial properties?
#
#
# === ANSWER ===
#
# Sorry, I couldn't find information about that.
#
# === SOURCES USED ===
#
# Source 1:
#   - Type: video
#   - Title: PropHero – Intro Video 3
#   - URL: https://www.youtube.com/watch?v=5Kca3nOrefY
#   - Chunk Preview: ugh out these key phase . phase number one , it s acquisition . we help you build a solid foundation with high growth property . number two , it s consolidation . we use each investment to feel the next . and number three be lifestyle . we handle pro...
#
# Source 2:
#   - Type: blog
#   - Title: Property vs Shares: What’s the Difference & Which is Better for You?
#   - URL: https://www.prophero.com/property-vs-shares-whats-the-difference-which-is-better-for-you/
#   - Chunk Preview: down all the time . in property , despite the change and boom , they be more stable over time and you win t be at risk of lose your investment the same way you could with the stock market . in short , both type of investment have their advantage , bu...
#
# Source 3:
#   - Type: video
#   - Title: PropHero – Intro Video 1
#   - URL: https://www.youtube.com/watch?v=ED3eypjlfrY
#   - Chunk Preview: hi , my name be michael roger . I m one of the co - founder of prop hero . in this video , I m go to show you how we be use datum to find the good deal . all right , let s start with the absolute basic . in a very , very simplified view , a great inv...
#
# Source 4:
#   - Type: blog
#   - Title: The Most Common Property Investment Mistakes That Can Easily Be Avoided
#   - URL: https://www.prophero.com/the-most-common-property-investment-mistakes-that-can-easily-be-avoided/
#   - Chunk Preview: re you live with service like prophero , you do not need to invest in property in your local area anymore . it may be tempting to go to open house in your local area on the weekend to see if you can snag a deal , but it s really not necessary . if yo...
#
# Source 5:
#   - Type: video
#   - Title: PropHero – Intro Video 1
#   - URL: https://www.youtube.com/watch?v=ED3eypjlfrY
#   - Chunk Preview: growth be about invest in an area where in the future , there will be strong demand and low supply . so think about grow population , grow economy , lack of land available , limited space to build new house . number two be buy under market price , ri...
#
# Source 6:
#   - Type: blog
#   - Title: The Most Common Property Investment Mistakes That Can Easily Be Avoided
#   - URL: https://www.prophero.com/the-most-common-property-investment-mistakes-that-can-easily-be-avoided/
#   - Chunk Preview: use your emotion to guide you it sound weird . we know . but buy property with your emotion be one of the big mistake we see many investor make everyday . maybe they want to invest or buy in an area close to home . or maybe they feel the late propert...
#
# Source 7:
#   - Type: blog
#   - Title: Property vs Shares: What’s the Difference & Which is Better for You?
#   - URL: https://www.prophero.com/property-vs-shares-whats-the-difference-which-is-better-for-you/
#   - Chunk Preview: how it work about us datum and ai press and blog how it work about us datum and ai press and blog en es book a free investment session prophero october 15 , 2025 property vs share what s the difference which be well for you there be so many option wh...
#
# Source 8:
#   - Type: video
#   - Title: PropHero – Intro Video 3
#   - URL: https://www.youtube.com/watch?v=5Kca3nOrefY
#   - Chunk Preview: neighborhood to find the good opportunity for you . we combine this with our expert insight to find high return investment , include off - market property that be not available to the public . so step two , we handle all the buying process for you . ...
#
# Source 9:
#   - Type: blog
#   - Title: Property vs Shares: What’s the Difference & Which is Better for You?
#   - URL: https://www.prophero.com/property-vs-shares-whats-the-difference-which-is-better-for-you/
#   - Chunk Preview: onth. The stock market is more volatile The stock markets are volatile. They go up and down all the time. In property, despite the changes and booms, they are more stable over time and you won’t be at risk of losing your investment the same way you c...
#
# Source 10:
#   - Type: video
#   - Title: PropHero – Intro Video 1
#   - URL: https://www.youtube.com/watch?v=ED3eypjlfrY
#   - Chunk Preview: , the quality of the school , crime rate , quality of the street , quality of the property as well . so think about , yeah , improvement potential , running cost , scarcity level , all of that . too many to cite right now , but yeah , we use over 200...
#
# Source 11:
#   - Type: blog
#   - Title: Are You Calculating Rental Yield Correctly?
#   - URL: https://www.prophero.com/are-you-calculating-rental-yield-correctly/
#   - Chunk Preview: into account other expense associate with property ownership , such as property management fee , maintenance cost , property taxis , and insurance . net rental yield this calculation consider the net income from the property after deduct all associat...
#
# Source 12:
#   - Type: blog
#   - Title: The Most Common Property Investment Mistakes That Can Easily Be Avoided
#   - URL: https://www.prophero.com/the-most-common-property-investment-mistakes-that-can-easily-be-avoided/
#   - Chunk Preview: t prophero how it work datum ai resource press and blog refer a friend frequently ask question 2025 prophero all right reserve term and condition privacy policy cooky policy legal...
#
# Source 13:
#   - Type: video
#   - Title: PropHero – Intro Video 3
#   - URL: https://www.youtube.com/watch?v=5Kca3nOrefY
#   - Chunk Preview: portfolio use each successful investment to power the next , create a snowball of wealth over time . and that be why we create prop hero to help everyday aussie find , buy and manage high return low risk investment property . unlike other platform th...
#
# Source 14:
#   - Type: video
#   - Title: PropHero – Intro Video 1
#   - URL: https://www.youtube.com/watch?v=ED3eypjlfrY
#   - Chunk Preview: ght away . we actually have a team of , as of today , about like 14 property expert and datum expert who look at these property and run all the analysis that the datum can not see . so there be a real human component to check every single property wi...
#
# Source 15:
#   - Type: video
#   - Title: PropHero – Intro Video 2
#   - URL: https://www.youtube.com/watch?v=uxF2IObEzZg
#   - Chunk Preview: hi everyone , I m carol . I m part of the entrepreneurship and innovation ecosystem team , part of investment news at wale . I m here at the sydney startup hub today with one of our amazing founder , pablo , who s the co - founder of prop hero . pabl...
#
# Source 16:
#   - Type: blog
#   - Title: Capital Gains 101: A Simplified Guide for Smart Property Investing
#   - URL: https://www.prophero.com/capital-gains-101-a-simplified-guide-for-smart-property-investing/
#   - Chunk Preview: t journey with confidence ? take the first step towards financial success by book a free investment session with our expert . gain valuable insight , ask question , and kickstart your path to make informed investment decision . go back to blog book a...
#
#
#
#
# ============================================================
# ❓ Question 4: Who is one of the co-founders of PropHero?
#
#
# === ANSWER ===
#
# One of the co-founders of PropHero is Michael Roger.
#
# === SOURCES USED ===
#
# Source 1:
#   - Type: blog
#   - Title: The Most Common Property Investment Mistakes That Can Easily Be Avoided
#   - URL: https://www.prophero.com/the-most-common-property-investment-mistakes-that-can-easily-be-avoided/
#   - Chunk Preview: t prophero how it work datum ai resource press and blog refer a friend frequently ask question 2025 prophero all right reserve term and condition privacy policy cooky policy legal...
#
# Source 2:
#   - Type: blog
#   - Title: Capital Gains 101: A Simplified Guide for Smart Property Investing
#   - URL: https://www.prophero.com/capital-gains-101-a-simplified-guide-for-smart-property-investing/
#   - Chunk Preview: t journey with confidence ? take the first step towards financial success by book a free investment session with our expert . gain valuable insight , ask question , and kickstart your path to make informed investment decision . go back to blog book a...
#
# Source 3:
#   - Type: video
#   - Title: PropHero – Intro Video 2
#   - URL: https://www.youtube.com/watch?v=uxF2IObEzZg
#   - Chunk Preview: hi everyone , I m carol . I m part of the entrepreneurship and innovation ecosystem team , part of investment news at wale . I m here at the sydney startup hub today with one of our amazing founder , pablo , who s the co - founder of prop hero . pabl...
#
# Source 4:
#   - Type: video
#   - Title: PropHero – Intro Video 2
#   - URL: https://www.youtube.com/watch?v=uxF2IObEzZg
#   - Chunk Preview: ll share or you will tell it , hey , have you apply for this ? okay , then you well get a bit more . do you want to tell we a little bit about some accolade you ve recently win ? yes , we win the prop tech startup of the year . congratulation . yes ,...
#
# Source 5:
#   - Type: video
#   - Title: PropHero – Intro Video 1
#   - URL: https://www.youtube.com/watch?v=ED3eypjlfrY
#   - Chunk Preview: hi , my name be michael roger . I m one of the co - founder of prop hero . in this video , I m go to show you how we be use datum to find the good deal . all right , let s start with the absolute basic . in a very , very simplified view , a great inv...
#
# Source 6:
#   - Type: video
#   - Title: PropHero – Intro Video 3
#   - URL: https://www.youtube.com/watch?v=5Kca3nOrefY
#   - Chunk Preview: portfolio use each successful investment to power the next , create a snowball of wealth over time . and that be why we create prop hero to help everyday aussie find , buy and manage high return low risk investment property . unlike other platform th...
#
# Source 7:
#   - Type: video
#   - Title: PropHero – Intro Video 3
#   - URL: https://www.youtube.com/watch?v=5Kca3nOrefY
#   - Chunk Preview: r year to come . well , like sarah , an overworked nurse in her 30 . sarah know she need to invest , but she always feel overwhelmed by the process . and within 12 month of work with prop hero , she acquire two high - growth property and its own trac...
#
# Source 8:
#   - Type: video
#   - Title: PropHero – Intro Video 3
#   - URL: https://www.youtube.com/watch?v=5Kca3nOrefY
#   - Chunk Preview: y be now on track for early retirement and fully fund education for their kid . and this isn t a far off dream . this be a reality for prop hero client . they experience this every day . now , I know that you be think , but this sound great , but I d...
#
# Source 9:
#   - Type: blog
#   - Title: The Most Common Property Investment Mistakes That Can Easily Be Avoided
#   - URL: https://www.prophero.com/the-most-common-property-investment-mistakes-that-can-easily-be-avoided/
#   - Chunk Preview: re you live with service like prophero , you do not need to invest in property in your local area anymore . it may be tempting to go to open house in your local area on the weekend to see if you can snag a deal , but it s really not necessary . if yo...
#
# Source 10:
#   - Type: video
#   - Title: PropHero – Intro Video 2
#   - URL: https://www.youtube.com/watch?v=uxF2IObEzZg
#   - Chunk Preview: ywhere in the world . it s quite an ambitious problem to be solve and a good market to be do it in . we be very datum - bagged . that s where michael , my business partner , come from . he s a double degree mathematician , like super bright guy . I s...
#
#
#
#
# ============================================================
# ❓ Question 5: What kind of platform is PropHero described as?
#
#
# === ANSWER ===
#
# PropHero is described as an expert property investment partner that helps everyday Australians find, buy, and manage high return, low risk investment properties.
#
# === SOURCES USED ===
#
# Source 1:
#   - Type: video
#   - Title: PropHero – Intro Video 3
#   - URL: https://www.youtube.com/watch?v=5Kca3nOrefY
#   - Chunk Preview: portfolio use each successful investment to power the next , create a snowball of wealth over time . and that be why we create prop hero to help everyday aussie find , buy and manage high return low risk investment property . unlike other platform th...
#
# Source 2:
#   - Type: blog
#   - Title: The Most Common Property Investment Mistakes That Can Easily Be Avoided
#   - URL: https://www.prophero.com/the-most-common-property-investment-mistakes-that-can-easily-be-avoided/
#   - Chunk Preview: t prophero how it work datum ai resource press and blog refer a friend frequently ask question 2025 prophero all right reserve term and condition privacy policy cooky policy legal...
#
# Source 3:
#   - Type: video
#   - Title: PropHero – Intro Video 2
#   - URL: https://www.youtube.com/watch?v=uxF2IObEzZg
#   - Chunk Preview: hi everyone , I m carol . I m part of the entrepreneurship and innovation ecosystem team , part of investment news at wale . I m here at the sydney startup hub today with one of our amazing founder , pablo , who s the co - founder of prop hero . pabl...
#
# Source 4:
#   - Type: video
#   - Title: PropHero – Intro Video 1
#   - URL: https://www.youtube.com/watch?v=ED3eypjlfrY
#   - Chunk Preview: hi , my name be michael roger . I m one of the co - founder of prop hero . in this video , I m go to show you how we be use datum to find the good deal . all right , let s start with the absolute basic . in a very , very simplified view , a great inv...
#
# Source 5:
#   - Type: video
#   - Title: PropHero – Intro Video 2
#   - URL: https://www.youtube.com/watch?v=uxF2IObEzZg
#   - Chunk Preview: ll share or you will tell it , hey , have you apply for this ? okay , then you well get a bit more . do you want to tell we a little bit about some accolade you ve recently win ? yes , we win the prop tech startup of the year . congratulation . yes ,...
#
# Source 6:
#   - Type: video
#   - Title: PropHero – Intro Video 3
#   - URL: https://www.youtube.com/watch?v=5Kca3nOrefY
#   - Chunk Preview: r year to come . well , like sarah , an overworked nurse in her 30 . sarah know she need to invest , but she always feel overwhelmed by the process . and within 12 month of work with prop hero , she acquire two high - growth property and its own trac...
#
# Source 7:
#   - Type: blog
#   - Title: Capital Gains 101: A Simplified Guide for Smart Property Investing
#   - URL: https://www.prophero.com/capital-gains-101-a-simplified-guide-for-smart-property-investing/
#   - Chunk Preview: t journey with confidence ? take the first step towards financial success by book a free investment session with our expert . gain valuable insight , ask question , and kickstart your path to make informed investment decision . go back to blog book a...
#
# Source 8:
#   - Type: blog
#   - Title: Property vs Shares: What’s the Difference & Which is Better for You?
#   - URL: https://www.prophero.com/property-vs-shares-whats-the-difference-which-is-better-for-you/
#   - Chunk Preview: down all the time . in property , despite the change and boom , they be more stable over time and you win t be at risk of lose your investment the same way you could with the stock market . in short , both type of investment have their advantage , bu...
#
# Source 9:
#   - Type: blog
#   - Title: The Most Common Property Investment Mistakes That Can Easily Be Avoided
#   - URL: https://www.prophero.com/the-most-common-property-investment-mistakes-that-can-easily-be-avoided/
#   - Chunk Preview: re you live with service like prophero , you do not need to invest in property in your local area anymore . it may be tempting to go to open house in your local area on the weekend to see if you can snag a deal , but it s really not necessary . if yo...
#
# Source 10:
#   - Type: blog
#   - Title: Property vs Shares: What’s the Difference & Which is Better for You?
#   - URL: https://www.prophero.com/property-vs-shares-whats-the-difference-which-is-better-for-you/
#   - Chunk Preview: ow it works Data & AI Resources Press and Blogs Refer a friend Frequently asked questions 2025 | © PropHero | All rights reserved Terms and Conditions Privacy Policy Cookies Policy Legal...
#
# Source 11:
#   - Type: video
#   - Title: PropHero – Intro Video 1
#   - URL: https://www.youtube.com/watch?v=ED3eypjlfrY
#   - Chunk Preview: , the quality of the school , crime rate , quality of the street , quality of the property as well . so think about , yeah , improvement potential , running cost , scarcity level , all of that . too many to cite right now , but yeah , we use over 200...
#
# Source 12:
#   - Type: video
#   - Title: PropHero – Intro Video 1
#   - URL: https://www.youtube.com/watch?v=ED3eypjlfrY
#   - Chunk Preview: thousand and thousand of correlation to understand what be the predictive element of future growth . or what be the indicator we can look at today that will ensure you significantly outperform the market . and so here , for example , we see that unde...
#
# Source 13:
#   - Type: blog
#   - Title: The Most Common Property Investment Mistakes That Can Easily Be Avoided
#   - URL: https://www.prophero.com/the-most-common-property-investment-mistakes-that-can-easily-be-avoided/
#   - Chunk Preview: how it work about us datum and ai press and blog how it work about us datum and ai press and blog en es book a free investment session prophero october 13 , 2025 the most common property investment mistake that can easily be avoid believe it or not ,...
#
# Source 14:
#   - Type: blog
#   - Title: Capital Gains 101: A Simplified Guide for Smart Property Investing
#   - URL: https://www.prophero.com/capital-gains-101-a-simplified-guide-for-smart-property-investing/
#   - Chunk Preview: how it work about us datum and ai press and blog how it work about us datum and ai press and blog en es book a free investment session prophero march 4 , 2025 capital gain 101 a simplified guide for smart property investing so you re dive into the wo...
#
# Source 15:
#   - Type: video
#   - Title: PropHero – Intro Video 3
#   - URL: https://www.youtube.com/watch?v=5Kca3nOrefY
#   - Chunk Preview: y be now on track for early retirement and fully fund education for their kid . and this isn t a far off dream . this be a reality for prop hero client . they experience this every day . now , I know that you be think , but this sound great , but I d...
#
#
#
#
# ============================================================
# ❓ Question 6: What problem does PropHero aim to solve for investors?
#
#
# === ANSWER ===
#
# PropHero aims to digitize the property investment journey and help everyday Australians find, buy, and manage high return, low risk investment properties.
#
# === SOURCES USED ===
#
# Source 1:
#   - Type: blog
#   - Title: Capital Gains 101: A Simplified Guide for Smart Property Investing
#   - URL: https://www.prophero.com/capital-gains-101-a-simplified-guide-for-smart-property-investing/
#   - Chunk Preview: t journey with confidence ? take the first step towards financial success by book a free investment session with our expert . gain valuable insight , ask question , and kickstart your path to make informed investment decision . go back to blog book a...
#
# Source 2:
#   - Type: blog
#   - Title: The Most Common Property Investment Mistakes That Can Easily Be Avoided
#   - URL: https://www.prophero.com/the-most-common-property-investment-mistakes-that-can-easily-be-avoided/
#   - Chunk Preview: t prophero how it work datum ai resource press and blog refer a friend frequently ask question 2025 prophero all right reserve term and condition privacy policy cooky policy legal...
#
# Source 3:
#   - Type: video
#   - Title: PropHero – Intro Video 1
#   - URL: https://www.youtube.com/watch?v=ED3eypjlfrY
#   - Chunk Preview: hi , my name be michael roger . I m one of the co - founder of prop hero . in this video , I m go to show you how we be use datum to find the good deal . all right , let s start with the absolute basic . in a very , very simplified view , a great inv...
#
# Source 4:
#   - Type: video
#   - Title: PropHero – Intro Video 3
#   - URL: https://www.youtube.com/watch?v=5Kca3nOrefY
#   - Chunk Preview: portfolio use each successful investment to power the next , create a snowball of wealth over time . and that be why we create prop hero to help everyday aussie find , buy and manage high return low risk investment property . unlike other platform th...
#
# Source 5:
#   - Type: video
#   - Title: PropHero – Intro Video 3
#   - URL: https://www.youtube.com/watch?v=5Kca3nOrefY
#   - Chunk Preview: market without time , tool or knowledge can feel like you be try to serve a rubik s cube blindfold . and right now , you be probably ask yourself , which area should I be look at ? how do I know if a property be a good purchase ? when be the right ti...
#
# Source 6:
#   - Type: video
#   - Title: PropHero – Intro Video 2
#   - URL: https://www.youtube.com/watch?v=uxF2IObEzZg
#   - Chunk Preview: hi everyone , I m carol . I m part of the entrepreneurship and innovation ecosystem team , part of investment news at wale . I m here at the sydney startup hub today with one of our amazing founder , pablo , who s the co - founder of prop hero . pabl...
#
# Source 7:
#   - Type: blog
#   - Title: Property vs Shares: What’s the Difference & Which is Better for You?
#   - URL: https://www.prophero.com/property-vs-shares-whats-the-difference-which-is-better-for-you/
#   - Chunk Preview: down all the time . in property , despite the change and boom , they be more stable over time and you win t be at risk of lose your investment the same way you could with the stock market . in short , both type of investment have their advantage , bu...
#
# Source 8:
#   - Type: blog
#   - Title: The Most Common Property Investment Mistakes That Can Easily Be Avoided
#   - URL: https://www.prophero.com/the-most-common-property-investment-mistakes-that-can-easily-be-avoided/
#   - Chunk Preview: how it work about us datum and ai press and blog how it work about us datum and ai press and blog en es book a free investment session prophero october 13 , 2025 the most common property investment mistake that can easily be avoid believe it or not ,...
#
# Source 9:
#   - Type: video
#   - Title: PropHero – Intro Video 1
#   - URL: https://www.youtube.com/watch?v=ED3eypjlfrY
#   - Chunk Preview: thousand and thousand of correlation to understand what be the predictive element of future growth . or what be the indicator we can look at today that will ensure you significantly outperform the market . and so here , for example , we see that unde...
#
# Source 10:
#   - Type: video
#   - Title: PropHero – Intro Video 3
#   - URL: https://www.youtube.com/watch?v=5Kca3nOrefY
#   - Chunk Preview: ugh out these key phase . phase number one , it s acquisition . we help you build a solid foundation with high growth property . number two , it s consolidation . we use each investment to feel the next . and number three be lifestyle . we handle pro...
#
# Source 11:
#   - Type: blog
#   - Title: Property vs Shares: What’s the Difference & Which is Better for You?
#   - URL: https://www.prophero.com/property-vs-shares-whats-the-difference-which-is-better-for-you/
#   - Chunk Preview: tip and trick on the area and location to avoid if you re concerned about invest in property . the benefit of invest in share the stock market be know to be more liquid than invest in tangible property . the high the liquidity mean the fast you ll ha...
#
# Source 12:
#   - Type: blog
#   - Title: The Most Common Property Investment Mistakes That Can Easily Be Avoided
#   - URL: https://www.prophero.com/the-most-common-property-investment-mistakes-that-can-easily-be-avoided/
#   - Chunk Preview: use your emotion to guide you it sound weird . we know . but buy property with your emotion be one of the big mistake we see many investor make everyday . maybe they want to invest or buy in an area close to home . or maybe they feel the late propert...
#
# Source 13:
#   - Type: video
#   - Title: PropHero – Intro Video 3
#   - URL: https://www.youtube.com/watch?v=5Kca3nOrefY
#   - Chunk Preview: r year to come . well , like sarah , an overworked nurse in her 30 . sarah know she need to invest , but she always feel overwhelmed by the process . and within 12 month of work with prop hero , she acquire two high - growth property and its own trac...
#
# Source 14:
#   - Type: blog
#   - Title: The Most Common Property Investment Mistakes That Can Easily Be Avoided
#   - URL: https://www.prophero.com/the-most-common-property-investment-mistakes-that-can-easily-be-avoided/
#   - Chunk Preview: o snag a deal as quickly as possible , then you may not be give yourself enough time to do your due diligence with the property . there be over 200 variable our team check with every property we purchase for client , and if a property doesn t make th...
#
#
#
#
# ============================================================
# ❓ Question 7: What does PropHero send to users after they invest?
#
#
# === ANSWER ===
#
# Sorry, I couldn't find information about that.
#
# === SOURCES USED ===
#
# Source 1:
#   - Type: blog
#   - Title: Capital Gains 101: A Simplified Guide for Smart Property Investing
#   - URL: https://www.prophero.com/capital-gains-101-a-simplified-guide-for-smart-property-investing/
#   - Chunk Preview: t journey with confidence ? take the first step towards financial success by book a free investment session with our expert . gain valuable insight , ask question , and kickstart your path to make informed investment decision . go back to blog book a...
#
# Source 2:
#   - Type: blog
#   - Title: The Most Common Property Investment Mistakes That Can Easily Be Avoided
#   - URL: https://www.prophero.com/the-most-common-property-investment-mistakes-that-can-easily-be-avoided/
#   - Chunk Preview: t prophero how it work datum ai resource press and blog refer a friend frequently ask question 2025 prophero all right reserve term and condition privacy policy cooky policy legal...
#
# Source 3:
#   - Type: video
#   - Title: PropHero – Intro Video 3
#   - URL: https://www.youtube.com/watch?v=5Kca3nOrefY
#   - Chunk Preview: portfolio use each successful investment to power the next , create a snowball of wealth over time . and that be why we create prop hero to help everyday aussie find , buy and manage high return low risk investment property . unlike other platform th...
#
# Source 4:
#   - Type: video
#   - Title: PropHero – Intro Video 2
#   - URL: https://www.youtube.com/watch?v=uxF2IObEzZg
#   - Chunk Preview: hi everyone , I m carol . I m part of the entrepreneurship and innovation ecosystem team , part of investment news at wale . I m here at the sydney startup hub today with one of our amazing founder , pablo , who s the co - founder of prop hero . pabl...
#
# Source 5:
#   - Type: video
#   - Title: PropHero – Intro Video 1
#   - URL: https://www.youtube.com/watch?v=ED3eypjlfrY
#   - Chunk Preview: hi , my name be michael roger . I m one of the co - founder of prop hero . in this video , I m go to show you how we be use datum to find the good deal . all right , let s start with the absolute basic . in a very , very simplified view , a great inv...
#
# Source 6:
#   - Type: video
#   - Title: PropHero – Intro Video 2
#   - URL: https://www.youtube.com/watch?v=uxF2IObEzZg
#   - Chunk Preview: ll share or you will tell it , hey , have you apply for this ? okay , then you well get a bit more . do you want to tell we a little bit about some accolade you ve recently win ? yes , we win the prop tech startup of the year . congratulation . yes ,...
#
# Source 7:
#   - Type: video
#   - Title: PropHero – Intro Video 3
#   - URL: https://www.youtube.com/watch?v=5Kca3nOrefY
#   - Chunk Preview: r year to come . well , like sarah , an overworked nurse in her 30 . sarah know she need to invest , but she always feel overwhelmed by the process . and within 12 month of work with prop hero , she acquire two high - growth property and its own trac...
#
# Source 8:
#   - Type: blog
#   - Title: Are You Calculating Rental Yield Correctly?
#   - URL: https://www.prophero.com/are-you-calculating-rental-yield-correctly/
#   - Chunk Preview: into account other expense associate with property ownership , such as property management fee , maintenance cost , property taxis , and insurance . net rental yield this calculation consider the net income from the property after deduct all associat...
#
# Source 9:
#   - Type: blog
#   - Title: The Most Common Property Investment Mistakes That Can Easily Be Avoided
#   - URL: https://www.prophero.com/the-most-common-property-investment-mistakes-that-can-easily-be-avoided/
#   - Chunk Preview: re you live with service like prophero , you do not need to invest in property in your local area anymore . it may be tempting to go to open house in your local area on the weekend to see if you can snag a deal , but it s really not necessary . if yo...
#
# Source 10:
#   - Type: video
#   - Title: PropHero – Intro Video 1
#   - URL: https://www.youtube.com/watch?v=ED3eypjlfrY
#   - Chunk Preview: ght away . we actually have a team of , as of today , about like 14 property expert and datum expert who look at these property and run all the analysis that the datum can not see . so there be a real human component to check every single property wi...
#
# Source 11:
#   - Type: blog
#   - Title: The Most Common Property Investment Mistakes That Can Easily Be Avoided
#   - URL: https://www.prophero.com/the-most-common-property-investment-mistakes-that-can-easily-be-avoided/
#   - Chunk Preview: how it work about us datum and ai press and blog how it work about us datum and ai press and blog en es book a free investment session prophero october 13 , 2025 the most common property investment mistake that can easily be avoid believe it or not ,...
#
# Source 12:
#   - Type: video
#   - Title: PropHero – Intro Video 3
#   - URL: https://www.youtube.com/watch?v=5Kca3nOrefY
#   - Chunk Preview: market without time , tool or knowledge can feel like you be try to serve a rubik s cube blindfold . and right now , you be probably ask yourself , which area should I be look at ? how do I know if a property be a good purchase ? when be the right ti...
#
# Source 13:
#   - Type: video
#   - Title: PropHero – Intro Video 3
#   - URL: https://www.youtube.com/watch?v=5Kca3nOrefY
#   - Chunk Preview: into reality and start build last wealth . I would like to invite you for a free investment strategy session . and in this session , we work together to uncover your true financial aspiration and here we ll discuss when do you want to replace your cu...
#
# Source 14:
#   - Type: blog
#   - Title: Property vs Shares: What’s the Difference & Which is Better for You?
#   - URL: https://www.prophero.com/property-vs-shares-whats-the-difference-which-is-better-for-you/
#   - Chunk Preview: how it work about us datum and ai press and blog how it work about us datum and ai press and blog en es book a free investment session prophero october 15 , 2025 property vs share what s the difference which be well for you there be so many option wh...
#
# Source 15:
#   - Type: video
#   - Title: PropHero – Intro Video 3
#   - URL: https://www.youtube.com/watch?v=5Kca3nOrefY
#   - Chunk Preview: ugh out these key phase . phase number one , it s acquisition . we help you build a solid foundation with high growth property . number two , it s consolidation . we use each investment to feel the next . and number three be lifestyle . we handle pro...
#
# Source 16:
#   - Type: blog
#   - Title: Capital Gains 101: A Simplified Guide for Smart Property Investing
#   - URL: https://www.prophero.com/capital-gains-101-a-simplified-guide-for-smart-property-investing/
#   - Chunk Preview: how it work about us datum and ai press and blog how it work about us datum and ai press and blog en es book a free investment session prophero march 4 , 2025 capital gain 101 a simplified guide for smart property investing so you re dive into the wo...
#
#
#
#
# ============================================================
# ❓ Question 8: What is the capital of Brazil according to PropHero?
#
#
# === ANSWER ===
#
# Sorry, I couldn't find information about that.
#
# === SOURCES USED ===
#
# Source 1:
#   - Type: video
#   - Title: PropHero – Intro Video 1
#   - URL: https://www.youtube.com/watch?v=ED3eypjlfrY
#   - Chunk Preview: than this . and we use over 100 variable , over 10 million datum point to track the entire country . so 15,000 suburb in australia , we track the entire country all the time . and here for these variable , think about macroeconomic like population gr...
#
# Source 2:
#   - Type: video
#   - Title: PropHero – Intro Video 1
#   - URL: https://www.youtube.com/watch?v=ED3eypjlfrY
#   - Chunk Preview: hi , my name be michael roger . I m one of the co - founder of prop hero . in this video , I m go to show you how we be use datum to find the good deal . all right , let s start with the absolute basic . in a very , very simplified view , a great inv...
#
# Source 3:
#   - Type: video
#   - Title: PropHero – Intro Video 2
#   - URL: https://www.youtube.com/watch?v=uxF2IObEzZg
#   - Chunk Preview: hi everyone , I m carol . I m part of the entrepreneurship and innovation ecosystem team , part of investment news at wale . I m here at the sydney startup hub today with one of our amazing founder , pablo , who s the co - founder of prop hero . pabl...
#
# Source 4:
#   - Type: video
#   - Title: PropHero – Intro Video 3
#   - URL: https://www.youtube.com/watch?v=5Kca3nOrefY
#   - Chunk Preview: portfolio use each successful investment to power the next , create a snowball of wealth over time . and that be why we create prop hero to help everyday aussie find , buy and manage high return low risk investment property . unlike other platform th...
#
# Source 5:
#   - Type: blog
#   - Title: The Most Common Property Investment Mistakes That Can Easily Be Avoided
#   - URL: https://www.prophero.com/the-most-common-property-investment-mistakes-that-can-easily-be-avoided/
#   - Chunk Preview: t prophero how it work datum ai resource press and blog refer a friend frequently ask question 2025 prophero all right reserve term and condition privacy policy cooky policy legal...
#
# Source 6:
#   - Type: video
#   - Title: PropHero – Intro Video 1
#   - URL: https://www.youtube.com/watch?v=ED3eypjlfrY
#   - Chunk Preview: , the quality of the school , crime rate , quality of the street , quality of the property as well . so think about , yeah , improvement potential , running cost , scarcity level , all of that . too many to cite right now , but yeah , we use over 200...
#
# Source 7:
#   - Type: video
#   - Title: PropHero – Intro Video 3
#   - URL: https://www.youtube.com/watch?v=5Kca3nOrefY
#   - Chunk Preview: ugh out these key phase . phase number one , it s acquisition . we help you build a solid foundation with high growth property . number two , it s consolidation . we use each investment to feel the next . and number three be lifestyle . we handle pro...
#
# Source 8:
#   - Type: blog
#   - Title: Capital Gains 101: A Simplified Guide for Smart Property Investing
#   - URL: https://www.prophero.com/capital-gains-101-a-simplified-guide-for-smart-property-investing/
#   - Chunk Preview: t journey with confidence ? take the first step towards financial success by book a free investment session with our expert . gain valuable insight , ask question , and kickstart your path to make informed investment decision . go back to blog book a...
#
# Source 9:
#   - Type: blog
#   - Title: The Most Common Property Investment Mistakes That Can Easily Be Avoided
#   - URL: https://www.prophero.com/the-most-common-property-investment-mistakes-that-can-easily-be-avoided/
#   - Chunk Preview: re you live with service like prophero , you do not need to invest in property in your local area anymore . it may be tempting to go to open house in your local area on the weekend to see if you can snag a deal , but it s really not necessary . if yo...
#
# Source 10:
#   - Type: blog
#   - Title: The Most Common Property Investment Mistakes That Can Easily Be Avoided
#   - URL: https://www.prophero.com/the-most-common-property-investment-mistakes-that-can-easily-be-avoided/
#   - Chunk Preview: use your emotion to guide you it sound weird . we know . but buy property with your emotion be one of the big mistake we see many investor make everyday . maybe they want to invest or buy in an area close to home . or maybe they feel the late propert...
#
# Source 11:
#   - Type: video
#   - Title: PropHero – Intro Video 1
#   - URL: https://www.youtube.com/watch?v=ED3eypjlfrY
#   - Chunk Preview: ght away . we actually have a team of , as of today , about like 14 property expert and datum expert who look at these property and run all the analysis that the datum can not see . so there be a real human component to check every single property wi...
#
# Source 12:
#   - Type: video
#   - Title: PropHero – Intro Video 3
#   - URL: https://www.youtube.com/watch?v=5Kca3nOrefY
#   - Chunk Preview: property investment be a game that anyone can win . it be not just for the elite or for the lucky few . it s for everyday aussie just like you , who dream of a financial freedom and a secure future . but despite this , 98 % of aussie state all the si...
#
# Source 13:
#   - Type: blog
#   - Title: Capital Gains 101: A Simplified Guide for Smart Property Investing
#   - URL: https://www.prophero.com/capital-gains-101-a-simplified-guide-for-smart-property-investing/
#   - Chunk Preview: how it work about us datum and ai press and blog how it work about us datum and ai press and blog en es book a free investment session prophero march 4 , 2025 capital gain 101 a simplified guide for smart property investing so you re dive into the wo...
#
# Source 14:
#   - Type: blog
#   - Title: Property vs Shares: What’s the Difference & Which is Better for You?
#   - URL: https://www.prophero.com/property-vs-shares-whats-the-difference-which-is-better-for-you/
#   - Chunk Preview: tip and trick on the area and location to avoid if you re concerned about invest in property . the benefit of invest in share the stock market be know to be more liquid than invest in tangible property . the high the liquidity mean the fast you ll ha...
#
# Source 15:
#   - Type: blog
#   - Title: Property vs Shares: What’s the Difference & Which is Better for You?
#   - URL: https://www.prophero.com/property-vs-shares-whats-the-difference-which-is-better-for-you/
#   - Chunk Preview: down all the time . in property , despite the change and boom , they be more stable over time and you win t be at risk of lose your investment the same way you could with the stock market . in short , both type of investment have their advantage , bu...
#
# Source 16:
#   - Type: video
#   - Title: PropHero – Intro Video 1
#   - URL: https://www.youtube.com/watch?v=ED3eypjlfrY
#   - Chunk Preview: thousand and thousand of correlation to understand what be the predictive element of future growth . or what be the indicator we can look at today that will ensure you significantly outperform the market . and so here , for example , we see that unde...
#
#
#
#
# ============================================================
# ❓ Question 9: Does the text describe safari tourism in Africa?
#
#
# === ANSWER ===
#
# Sorry, I couldn't find information about that.
#
# === SOURCES USED ===
#
# Source 1:
#   - Type: blog
#   - Title: The Most Common Property Investment Mistakes That Can Easily Be Avoided
#   - URL: https://www.prophero.com/the-most-common-property-investment-mistakes-that-can-easily-be-avoided/
#   - Chunk Preview: t prophero how it work datum ai resource press and blog refer a friend frequently ask question 2025 prophero all right reserve term and condition privacy policy cooky policy legal...
#
# Source 2:
#   - Type: blog
#   - Title: Capital Gains 101: A Simplified Guide for Smart Property Investing
#   - URL: https://www.prophero.com/capital-gains-101-a-simplified-guide-for-smart-property-investing/
#   - Chunk Preview: t journey with confidence ? take the first step towards financial success by book a free investment session with our expert . gain valuable insight , ask question , and kickstart your path to make informed investment decision . go back to blog book a...
#
# Source 3:
#   - Type: video
#   - Title: PropHero – Intro Video 3
#   - URL: https://www.youtube.com/watch?v=5Kca3nOrefY
#   - Chunk Preview: market without time , tool or knowledge can feel like you be try to serve a rubik s cube blindfold . and right now , you be probably ask yourself , which area should I be look at ? how do I know if a property be a good purchase ? when be the right ti...
#
# Source 4:
#   - Type: video
#   - Title: PropHero – Intro Video 1
#   - URL: https://www.youtube.com/watch?v=ED3eypjlfrY
#   - Chunk Preview: growth be about invest in an area where in the future , there will be strong demand and low supply . so think about grow population , grow economy , lack of land available , limited space to build new house . number two be buy under market price , ri...
#
# Source 5:
#   - Type: video
#   - Title: PropHero – Intro Video 3
#   - URL: https://www.youtube.com/watch?v=5Kca3nOrefY
#   - Chunk Preview: into reality and start build last wealth . I would like to invite you for a free investment strategy session . and in this session , we work together to uncover your true financial aspiration and here we ll discuss when do you want to replace your cu...
#
# Source 6:
#   - Type: video
#   - Title: PropHero – Intro Video 2
#   - URL: https://www.youtube.com/watch?v=uxF2IObEzZg
#   - Chunk Preview: hi everyone , I m carol . I m part of the entrepreneurship and innovation ecosystem team , part of investment news at wale . I m here at the sydney startup hub today with one of our amazing founder , pablo , who s the co - founder of prop hero . pabl...
#
# Source 7:
#   - Type: video
#   - Title: PropHero – Intro Video 2
#   - URL: https://www.youtube.com/watch?v=uxF2IObEzZg
#   - Chunk Preview: commit to not have a vacation or be pay nothing . there s a lot into it , but it fulfill you a lot . that s great . thank you so much . awesome . thank you very much ....
#
# Source 8:
#   - Type: blog
#   - Title: Are You Calculating Rental Yield Correctly?
#   - URL: https://www.prophero.com/are-you-calculating-rental-yield-correctly/
#   - Chunk Preview: logs Refer a friend Frequently asked questions 2025 | © PropHero | All rights reserved Terms and Conditions Privacy Policy Cookies Policy Legal...
#
# Source 9:
#   - Type: video
#   - Title: PropHero – Intro Video 3
#   - URL: https://www.youtube.com/watch?v=5Kca3nOrefY
#   - Chunk Preview: ugh out these key phase . phase number one , it s acquisition . we help you build a solid foundation with high growth property . number two , it s consolidation . we use each investment to feel the next . and number three be lifestyle . we handle pro...
#
# Source 10:
#   - Type: video
#   - Title: PropHero – Intro Video 3
#   - URL: https://www.youtube.com/watch?v=5Kca3nOrefY
#   - Chunk Preview: h level demand , we only have capacity for 15 session per week and sport be fill up fast . so if you be serious about create a life of financial freedom and last wealth for you and your family , click and book now and don t let another day go by watc...
#
# Source 11:
#   - Type: blog
#   - Title: Property vs Shares: What’s the Difference & Which is Better for You?
#   - URL: https://www.prophero.com/property-vs-shares-whats-the-difference-which-is-better-for-you/
#   - Chunk Preview: ow it works Data & AI Resources Press and Blogs Refer a friend Frequently asked questions 2025 | © PropHero | All rights reserved Terms and Conditions Privacy Policy Cookies Policy Legal...
#
# Source 12:
#   - Type: video
#   - Title: PropHero – Intro Video 3
#   - URL: https://www.youtube.com/watch?v=5Kca3nOrefY
#   - Chunk Preview: neighborhood to find the good opportunity for you . we combine this with our expert insight to find high return investment , include off - market property that be not available to the public . so step two , we handle all the buying process for you . ...
#
# Source 13:
#   - Type: video
#   - Title: PropHero – Intro Video 1
#   - URL: https://www.youtube.com/watch?v=ED3eypjlfrY
#   - Chunk Preview: about cash flow . cash flow be more straightforward , right ? you want to have a high rental yield . so your rental yield be the annual rent you be receive divide by the price of your property . number two , what you want to focus on be in area with ...
#
# Source 14:
#   - Type: video
#   - Title: PropHero – Intro Video 3
#   - URL: https://www.youtube.com/watch?v=5Kca3nOrefY
#   - Chunk Preview: rvice , to financial advice , to property management , our vetted partner handle everything you need to succeed through your investment journey . with over one billion in asset , we have prove expertise and track record to guide your property investm...
#
# Source 15:
#   - Type: video
#   - Title: PropHero – Intro Video 3
#   - URL: https://www.youtube.com/watch?v=5Kca3nOrefY
#   - Chunk Preview: , will determine whether a high growth or a cash flow focus portfolio suit you well , and then we ll design a custom property roadmap . we ll outline the exact step you need to take , align with your income replacement timeline to turn your property ...
#
# Source 16:
#   - Type: video
#   - Title: PropHero – Intro Video 1
#   - URL: https://www.youtube.com/watch?v=ED3eypjlfrY
#   - Chunk Preview: than this . and we use over 100 variable , over 10 million datum point to track the entire country . so 15,000 suburb in australia , we track the entire country all the time . and here for these variable , think about macroeconomic like population gr...

# %% [markdown]
# 3.9 Evaluation ROUGE & BLEU
#
# **ROUGE** -->  Did the model capture the most important ideas?. *Precision* what % of generated words are correct?
#
# **BLEU** --> Did the model use the same words as the correct answer? *Recall* = how much meaning from the expected answer was recovered?

# %%
# !pip install rouge-score sacrebleu
# Out:
# Requirement already satisfied: rouge-score in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (0.1.2)
# Requirement already satisfied: sacrebleu in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (2.5.1)
# Requirement already satisfied: absl-py in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from rouge-score) (2.3.1)
# Requirement already satisfied: nltk in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from rouge-score) (3.9.2)
# Requirement already satisfied: numpy in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from rouge-score) (2.3.4)
# Requirement already satisfied: six>=1.14.0 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from rouge-score) (1.17.0)
# Requirement already satisfied: portalocker in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from sacrebleu) (3.2.0)
# Requirement already satisfied: regex in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from sacrebleu) (2025.11.3)
# Requirement already satisfied: tabulate>=0.8.9 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: colorama in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from sacrebleu) (0.4.6)
# Requirement already satisfied: lxml in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from sacrebleu) (6.0.2)
# Requirement already satisfied: click in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from nltk->rouge-score) (8.3.1)
# Requirement already satisfied: joblib in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from nltk->rouge-score) (1.5.2)
# Requirement already satisfied: tqdm in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from nltk->rouge-score) (4.67.1)
# Requirement already satisfied: pywin32>=226 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from portalocker->sacrebleu) (311)

# %%
from rouge_score import rouge_scorer
import sacrebleu

def evaluate_rag_generation(system_answers, reference_answers):
    """
    system_answers: list of answers generated by your RAG system
    reference_answers: list of expected correct answers (YOU must define them)
    """

    bleu = sacrebleu.corpus_bleu(system_answers, [reference_answers]).score

    scorer = rouge_scorer.RougeScorer(['rougeL'], use_stemmer=True)
    rouge_scores = [
        scorer.score(ref, sys)["rougeL"].fmeasure
        for sys, ref in zip(system_answers, reference_answers)
    ]
    
    rougeL = sum(rouge_scores) / len(rouge_scores)

    return {"BLEU": bleu, "ROUGE-L": rougeL}

# %%
test_questions = [
    "Is PropHero a company that focuses on property investment?",
    "Does PropHero use artificial intelligence for decision-making?",
    "What kind of platform is PropHero described as?",
    "Who is one of the co-founders of PropHero?"
]

reference_answers = [
    "Yes, PropHero focuses on property investment.",
    "Yes, PropHero uses AI to support decision-making.",
    "PropHero is described as a smart digital property investment platform.",
    "One of the co-founders of PropHero is Pablo Cebrián."
]

# %%
system_answers = []

for q in test_questions:
    result = qa_chain.invoke({"query": q})
    system_answers.append(result["result"])

system_answers
# Out:
# ['Yes, PropHero is a company that focuses on property investment.',
#  'Yes, PropHero uses AI-powered data models to identify high return properties and guide investment decisions.',
#  'PropHero is described as an expert property investment partner that helps everyday Australians find, buy, and manage high return low risk investment properties.',
#  'One of the co-founders of PropHero is Michael Roger.']

# %%
metrics = evaluate_rag_generation(system_answers, reference_answers)
metrics
# Out:
# {'BLEU': 26.299515953323684, 'ROUGE-L': 0.5938852813852814}

# %% [markdown]
# Output:
# - BLEU = 10.8 --> Weak
# - ROUGE = 0.40 --> Good, captures meaning but not perfectly

# %% [markdown]
# 3.10 Evaluation RAGAS (Faithfulness, answer relevancy, context recall, context precision, answer correctness)

# %%
# !pip install -q "ragas>=0.1.7" datasets

# %%
pip install --upgrade huggingface_hub datasets ragas
# Out:
# Requirement already satisfied: huggingface_hub in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (0.36.0)
# Collecting huggingface_hub
#   Using cached huggingface_hub-1.1.5-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: datasets in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (4.4.1)
# Requirement already satisfied: ragas in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (0.3.9)
# Requirement already satisfied: filelock in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from huggingface_hub) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from huggingface_hub) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from huggingface_hub) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from huggingface_hub) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from huggingface_hub) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from huggingface_hub) (6.0.3)
# Requirement already satisfied: shellingham in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from huggingface_hub) (1.5.4)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from huggingface_hub) (4.67.1)
# Requirement already satisfied: typer-slim in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from huggingface_hub) (0.20.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from huggingface_hub) (4.15.0)
# Requirement already satisfied: anyio in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub) (4.11.0)
# Requirement already satisfied: certifi in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub) (1.0.9)
# Requirement already satisfied: idna in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub) (0.16.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from datasets) (2.3.4)
# Requirement already satisfied: pyarrow>=21.0.0 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from datasets) (21.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from datasets) (0.4.0)
# Requirement already satisfied: pandas in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from datasets) (2.3.3)
# Requirement already satisfied: requests>=2.32.2 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from datasets) (2.32.5)
# Requirement already satisfied: xxhash in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.19 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from datasets) (0.70.18)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (3.13.2)
# Requirement already satisfied: tiktoken in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from ragas) (0.12.0)
# Requirement already satisfied: pydantic>=2.0.0 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from ragas) (2.12.4)
# Requirement already satisfied: nest-asyncio in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from ragas) (1.6.0)
# Requirement already satisfied: appdirs in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from ragas) (1.4.4)
# Requirement already satisfied: diskcache>=5.6.3 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from ragas) (5.6.3)
# Requirement already satisfied: typer in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from ragas) (0.20.0)
# Requirement already satisfied: rich in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from ragas) (14.2.0)
# Requirement already satisfied: openai>=1.0.0 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from ragas) (2.8.0)
# Requirement already satisfied: instructor in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from ragas) (1.13.0)
# Requirement already satisfied: gitpython in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from ragas) (3.1.45)
# Requirement already satisfied: pillow>=10.4.0 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from ragas) (12.0.0)
# Requirement already satisfied: networkx in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from ragas) (3.5)
# Requirement already satisfied: scikit-network in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from ragas) (0.33.5)
# Requirement already satisfied: langchain in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from ragas) (0.3.27)
# Requirement already satisfied: langchain-core in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from ragas) (0.3.79)
# Requirement already satisfied: langchain-community in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from ragas) (0.3.31)
# Requirement already satisfied: langchain_openai in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from ragas) (0.3.35)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from openai>=1.0.0->ragas) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from openai>=1.0.0->ragas) (0.11.1)
# Requirement already satisfied: sniffio in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from openai>=1.0.0->ragas) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from pydantic>=2.0.0->ragas) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from pydantic>=2.0.0->ragas) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from pydantic>=2.0.0->ragas) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from requests>=2.32.2->datasets) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from requests>=2.32.2->datasets) (2.3.0)
# Requirement already satisfied: colorama in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from tqdm>=4.42.1->huggingface_hub) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from gitpython->ragas) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from gitdb<5,>=4.0.1->gitpython->ragas) (5.0.2)
# Requirement already satisfied: docstring-parser<1.0,>=0.16 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from instructor->ragas) (0.17.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.4 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from instructor->ragas) (3.1.6)
# Requirement already satisfied: pre-commit>=4.3.0 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from instructor->ragas) (4.4.0)
# Requirement already satisfied: tenacity<10.0.0,>=8.2.3 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from instructor->ragas) (9.1.2)
# Requirement already satisfied: ty>=0.0.1a23 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from instructor->ragas) (0.0.1a27)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from jinja2<4.0.0,>=3.1.4->instructor->ragas) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from rich->ragas) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from rich->ragas) (2.19.2)
# Requirement already satisfied: click>=8.0.0 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from typer->ragas) (8.3.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from markdown-it-py>=2.2.0->rich->ragas) (0.1.2)
# Requirement already satisfied: cfgv>=2.0.0 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from pre-commit>=4.3.0->instructor->ragas) (3.5.0)
# Requirement already satisfied: identify>=1.0.0 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from pre-commit>=4.3.0->instructor->ragas) (2.6.15)
# Requirement already satisfied: nodeenv>=0.11.1 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from pre-commit>=4.3.0->instructor->ragas) (1.9.1)
# Requirement already satisfied: virtualenv>=20.10.0 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from pre-commit>=4.3.0->instructor->ragas) (20.35.4)
# Requirement already satisfied: distlib<1,>=0.3.7 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from virtualenv>=20.10.0->pre-commit>=4.3.0->instructor->ragas) (0.4.0)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from virtualenv>=20.10.0->pre-commit>=4.3.0->instructor->ragas) (4.5.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from langchain->ragas) (0.3.11)
# Requirement already satisfied: langsmith>=0.1.17 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from langchain->ragas) (0.4.43)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from langchain->ragas) (2.0.44)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from langchain-core->ragas) (1.33)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core->ragas) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from langsmith>=0.1.17->langchain->ragas) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from langsmith>=0.1.17->langchain->ragas) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from langsmith>=0.1.17->langchain->ragas) (0.25.0)
# Requirement already satisfied: greenlet>=1 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain->ragas) (3.2.4)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from langchain-community->ragas) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from langchain-community->ragas) (2.12.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from langchain-community->ragas) (0.4.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community->ragas) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community->ragas) (0.9.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community->ragas) (1.2.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community->ragas) (1.1.0)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from tiktoken->ragas) (2025.11.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: scipy>=1.7.3 in c:\users\macat\anaconda3\envs\langchain-mq\lib\site-packages (from scikit-network->ragas) (1.16.3)
# Using cached huggingface_hub-1.1.5-py3-none-any.whl (516 kB)
# Installing collected packages: huggingface_hub
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface-hub 0.36.0
#     Uninstalling huggingface-hub-0.36.0:
#       Successfully uninstalled huggingface-hub-0.36.0
# Successfully installed huggingface_hub-1.1.5
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-huggingface 1.0.1 requires huggingface-hub<1.0.0,>=0.33.4, but you have huggingface-hub 1.1.5 which is incompatible.
# langchain-huggingface 1.0.1 requires langchain-core<2.0.0,>=1.0.3, but you have langchain-core 0.3.79 which is incompatible.
# transformers 4.57.1 requires huggingface-hub<1.0,>=0.34.0, but you have huggingface-hub 1.1.5 which is incompatible.

# %%
from datasets import Dataset

from ragas import evaluate
from ragas.metrics import (
    answer_relevancy,   # how well the answer matches the question
    faithfulness,       # hallucinations vs context
    context_precision,  # how much of retrieved context is actually useful
    context_recall,     # did we retrieve the needed info?
)

# %%
def build_ragas_dataset(questions, reference_answers, rag_chain, max_contexts: int = 5):
    """
    Run your RAG chain on a list of questions and build a RAGAS dataset.

    questions: list[str]
    reference_answers: list[str] – gold answers you wrote manually
    rag_chain: your RetrievalQA chain (qa_chain)
    max_contexts: how many retrieved chunks per question to keep
    """
    assert len(questions) == len(reference_answers), "questions and reference_answers must have same length"

    rows = []

    for q, gt in zip(questions, reference_answers):
        # 1) Call your RAG system
        result = rag_chain.invoke({"query": q})

        # 2) Extract answer from the chain output
        answer = result["result"]

        # 3) Extract textual contexts from retrieved documents
        source_docs = result.get("source_documents", [])
        contexts = [doc.page_content for doc in source_docs[:max_contexts]]

        # 4) Add row for RAGAS
        rows.append(
            {
                "question": q,
                "answer": answer,
                "contexts": contexts,
                "ground_truth": gt,
            }
        )

    # Convert to HF Dataset
    return Dataset.from_list(rows)

# %%
ragas_dataset = build_ragas_dataset(
    questions=test_questions,
    reference_answers=reference_answers,
    rag_chain=qa_chain,
    max_contexts=5,   # you can tune this
)

ragas_dataset
# Out:
# Dataset({
#     features: ['question', 'answer', 'contexts', 'ground_truth'],
#     num_rows: 4
# })
